# %% [markdown]
# # Interactive Unit Distance Explorer
#
# Enter custom rational coordinates and validate them exactly.

# %%
# !pip install -q sympy

import sys
sys.path.insert(0, "..")
from counterexample_commons.validators import validate_custom_configuration

# %%
# Example: unit square
coords = [("0", "0"), ("1", "0"), ("1", "1"), ("0", "1")]
result = validate_custom_configuration(coords)
print(f"Points: {result['n']}, Edges: {result['actual_edges']}")

# %%
# Try your own coordinates
my_coords = [
    ("0", "0"),
    ("1", "0"),
    # Add more points here
]
result = validate_custom_configuration(my_coords)
print(result)
