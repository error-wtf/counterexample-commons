# %% [markdown]
# # Public Baseline Demo Only
#
# Safe public demo: exact baselines only, no AI providers, no secrets.

# %%
# !pip install -q sympy numpy matplotlib gradio

# %%
import sys, os
sys.path.insert(0, ".")
os.environ["COUNTEREXAMPLE_MODE"] = "colab-public-demo"

from app.main import build_app
from counterexample_commons.config import AppMode

demo = build_app(mode=AppMode.COLAB_PUBLIC_DEMO)
demo.launch(share=True)
